# %% [markdown]
# Databricks Bronze Layer Notebook

# %%
cad_df = spark.read.option("header",True) \
.csv("/mnt/bronze/cad_metadata")

cad_df.write.format("delta") \
.mode("append") \
.save("/mnt/delta/bronze/cad_metadata")
